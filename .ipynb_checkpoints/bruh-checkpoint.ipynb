# %%
import pandas as pd
import math
import random
import numpy as np
import seaborn as sns

# %%
data=pd.read_csv('../data/bruh.csv')

# %%
data
# Out:
#        pol_number  pol_eff_dt gender  agecat date_of_birth  credit_score area  \
# 0        43124327  12/30/2020      F     4.0     7/12/1968         381.0    D
# 1        21919609  12/30/2020      F     2.0     11/5/1982         549.0    D
# 2        72577057  12/30/2020      M     2.0    11/26/1983         649.0    B
# 3        92175225  12/30/2020      M     4.0     11/2/1960         743.0    B
# 4        66223239  12/30/2020      F     4.0      1/4/1968         817.0    C
# ...           ...         ...    ...     ...           ...           ...  ...
# 60387    73248694    1/2/2020      F     5.0     5/10/1956         809.0    C
# 60388    71411764    1/2/2020      M     4.0     3/22/1961         681.0    D
# 60389    89353155    1/2/2020      M     4.0     9/29/1965         773.0    F
# 60390    40916605    1/2/2020      M     3.0      8/1/1978         714.0    B
# 60391    33623054    1/2/2020      F     3.0    12/12/1973           NaN    D
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60392 entries, 0 to 60391
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   pol_number      60392 non-null  int64
#  1   pol_eff_dt      60392 non-null  object
#  2   gender          60392 non-null  object
#  3   agecat          55561 non-null  float64
#  4   date_of_birth   60392 non-null  object
#  5   credit_score    57591 non-null  float64
#  6   area            60392 non-null  object
#  7   traffic_index   56889 non-null  float64
#  8   veh_age         60392 non-null  int64
#  9   veh_body        60392 non-null  object
#  10  veh_value       60392 non-null  float64
#  11  claim_office    10030 non-null  object
#  12  numclaims       60392 non-null  int64
#  13  claimcst0       60392 non-null  float64
#  14  annual_premium  60392 non-null  float64
# dtypes: float64(6), int64(3), object(6)
# memory usage: 6.9+ MB

# %%
data['annual_premium'].describe()
# Out:
# count    60392.00
# mean       716.53
# std          0.00
# min        716.53
# 25%        716.53
# 50%        716.53
# 75%        716.53
# max        716.53
# Name: annual_premium, dtype: float64

# %%
data.drop("annual_premium",axis=1)
# Out:
#        pol_number  pol_eff_dt gender  agecat date_of_birth  credit_score area  \
# 0        43124327  12/30/2020      F     4.0     7/12/1968         381.0    D
# 1        21919609  12/30/2020      F     2.0     11/5/1982         549.0    D
# 2        72577057  12/30/2020      M     2.0    11/26/1983         649.0    B
# 3        92175225  12/30/2020      M     4.0     11/2/1960         743.0    B
# 4        66223239  12/30/2020      F     4.0      1/4/1968         817.0    C
# ...           ...         ...    ...     ...           ...           ...  ...
# 60387    73248694    1/2/2020      F     5.0     5/10/1956         809.0    C
# 60388    71411764    1/2/2020      M     4.0     3/22/1961         681.0    D
# 60389    89353155    1/2/2020      M     4.0     9/29/1965         773.0    F
# 60390    40916605    1/2/2020      M     3.0      8/1/1978         714.0    B
# 60391    33623054    1/2/2020      F     3.0    12/12/1973           NaN    D
#
# ...

# %%
newcol=[]
for i in range (0,len(data.index)):
    r=random.randint(-60,40)
    #increase range into 1000s and then divide by 0.0001 to make numbers more random
    r*=0.01
    newcol.append(math.floor(14250+(14250*r)))

# %%
data.insert(8,"mileage",newcol)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 60391 entries, 0 to 60391
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   pol_number     60391 non-null  int64
#  1   pol_eff_dt     60391 non-null  object
#  2   gender         60391 non-null  object
#  3   agecat         55561 non-null  float64
#  4   date_of_birth  60391 non-null  object
#  5   credit_score   57590 non-null  float64
#  6   area           60391 non-null  object
#  7   traffic_index  60391 non-null  float64
#  8   mileage        60391 non-null  Int64
#  9   veh_age        60391 non-null  int64
#  10  veh_body       60391 non-null  object
#  11  veh_value      60391 non-null  float64
#  12  claim_office   10030 non-null  object
#  13  numclaims      60391 non-null  int64
#  14  claimcst0      60391 non-null  float64
# dtypes: Int64(1), float64(5), int64(3), object(6)
# memory usage: 7.4+ MB

# %%
data["mileage"].describe()
# Out:
# count    60392.000000
# mean     12825.992814
# std       4147.273918
# min       5700.000000
# 25%       9262.000000
# 50%      12825.000000
# 75%      16387.000000
# max      19950.000000
# Name: mileage, dtype: float64

# %%
data['mileage'] = data['mileage'].astype('Int64')

# %%
data['mileage'].describe()
# Out:
# count         60392.0
# mean     12825.992814
# std       4147.273918
# min            5700.0
# 25%            9262.0
# 50%           12825.0
# 75%           16387.0
# max           19950.0
# Name: mileage, dtype: Float64

# %%
data
# Out:
#        pol_number  pol_eff_dt gender  agecat date_of_birth  credit_score area  \
# 0        43124327  12/30/2020      F     4.0     7/12/1968         381.0    D
# 1        21919609  12/30/2020      F     2.0     11/5/1982         549.0    D
# 2        72577057  12/30/2020      M     2.0    11/26/1983         649.0    B
# 3        92175225  12/30/2020      M     4.0     11/2/1960         743.0    B
# 4        66223239  12/30/2020      F     4.0      1/4/1968         817.0    C
# ...           ...         ...    ...     ...           ...           ...  ...
# 60387    73248694    1/2/2020      F     5.0     5/10/1956         809.0    C
# 60388    71411764    1/2/2020      M     4.0     3/22/1961         681.0    D
# 60389    89353155    1/2/2020      M     4.0     9/29/1965         773.0    F
# 60390    40916605    1/2/2020      M     3.0      8/1/1978         714.0    B
# 60391    33623054    1/2/2020      F     3.0    12/12/1973           NaN    D
#
# ...

# %%
data.drop("annual_premium",inplace=True,axis=1)

# %%
sns.boxplot(x=data["veh_value"])
# Out:
# <Axes: xlabel='veh_value'>

# %%
data.sort_values(by = 'veh_value', ascending = False)[:30]
# Out:
#        pol_number  pol_eff_dt gender  agecat date_of_birth  credit_score area  \
# 27023    80032241   7/21/2020      M     NaN      3/7/1972         594.0    A
# 26020    40994132   7/27/2020      F     3.0      3/7/1976         591.0    A
# 13510    10573012  10/11/2020      M     6.0    12/28/1946         804.0    A
# 15452    47704708   9/29/2020      M     1.0     7/23/1990         682.0    C
# 46901    34012753   3/23/2020      M     4.0      7/3/1960         810.0    C
# 31574    22396883   6/23/2020      M     1.0    10/15/1998         657.0    A
# 5992     92066522  11/25/2020      M     NaN     5/15/1964         652.0    A
# 4173     42452841   12/6/2020      F     3.0     7/29/1973         684.0    A
# 1172     26103841  12/23/2020      M     4.0     7/23/1964         637.0    A
# 52356    92352615   2/19/2020      M     3.0     7/24/1972         656.0    A
# 6909     32969993  11/19/2020      M     5.0     3/20/1955         790.0    A
# ...

# %%
data=data.drop(data.index[26062])

# %%
data
# Out:
#        pol_number  pol_eff_dt gender  agecat date_of_birth  credit_score area  \
# 0        43124327  12/30/2020      F     4.0     7/12/1968         381.0    D
# 1        21919609  12/30/2020      F     2.0     11/5/1982         549.0    D
# 2        72577057  12/30/2020      M     2.0    11/26/1983         649.0    B
# 3        92175225  12/30/2020      M     4.0     11/2/1960         743.0    B
# 4        66223239  12/30/2020      F     4.0      1/4/1968         817.0    C
# ...           ...         ...    ...     ...           ...           ...  ...
# 60387    73248694    1/2/2020      F     5.0     5/10/1956         809.0    C
# 60388    71411764    1/2/2020      M     4.0     3/22/1961         681.0    D
# 60389    89353155    1/2/2020      M     4.0     9/29/1965         773.0    F
# 60390    40916605    1/2/2020      M     3.0      8/1/1978         714.0    B
# 60391    33623054    1/2/2020      F     3.0    12/12/1973           NaN    D
#
# ...

# %%
data['agecat'].describe()
# Out:
# count    55561.000000
# mean         3.488310
# std          1.425133
# min          1.000000
# 25%          2.000000
# 50%          3.000000
# 75%          5.000000
# max          6.000000
# Name: agecat, dtype: float64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 60391 entries, 0 to 60391
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   pol_number     60391 non-null  int64
#  1   pol_eff_dt     60391 non-null  object
#  2   gender         60391 non-null  object
#  3   agecat         55561 non-null  float64
#  4   date_of_birth  60391 non-null  object
#  5   credit_score   60391 non-null  float64
#  6   area           60391 non-null  object
#  7   traffic_index  60391 non-null  float64
#  8   mileage        60391 non-null  Int64
#  9   veh_age        60391 non-null  int64
#  10  veh_body       60391 non-null  object
#  11  veh_value      60391 non-null  float64
#  12  claim_office   10030 non-null  object
#  13  numclaims      60391 non-null  int64
#  14  claimcst0      60391 non-null  float64
# dtypes: Int64(1), float64(5), int64(3), object(6)
# memory usage: 9.4+ MB

# %%
median=data['traffic_index'].median()
data["traffic_index"].fillna(median, inplace = True)

# %%
median=data['credit_score'].median()
data["credit_score"].fillna(median, inplace = True)

# %%
median=data['agecat'].median()
data["agecat"].fillna(median, inplace = True)

# %%
w=100
newc=[]
for i in data.index:
    x=((data['mileage'][i]-12826)/12826)*50
    r=(random.randint(-15,15))/100
    x=x*(1+r)
    w=w+x
    x=((data['traffic_index'][i]-104)/104)*25
    r=(random.randint(-15,15))/100
    x=x*(1+r)
    w=w+x
    x=((data['veh_value'][i]-1.65)/1.65)*20
    r=(random.randint(-15,15))/100
    x=x*(1+r)
    w=w+x
    x=((data['numclaims'][i])*5)
    r=(random.randint(-15,15))/100
    x=x*(1+r)
    w=w+x
    x=((data['veh_age'][i])*3)
    r=(random.randint(-15,15))/100
    x=x*(1+r)
    w=w+x
    x=((data['agecat'][i])*2)
    r=(random.randint(-15,15))/100
    x=x*(1+r)
    w=w+x
    x=((data['credit_score'][i]-682)/682)*10
    r=(random.randint(-15,15))/100
    x=x*(1+r)
    w=w-x
    if(data['veh_body'][i]!="SEDAN" or data['veh_body'][i]!="HBACK" or data['veh_body'][i]!="COUPE"):
        r=(random.randint(0,3))
        w=w+r
    w=w/100
    val=math.floor(1469*w)
    newc.append(val)
    w=100
newc
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-93-87a5ca30ed09> in <module>
#      34         w=w+r
#      35     w=w/100
# ---> 36     val=math.floor(1469*w)
#      37     newc.append(val)
#      38     w=100
#
# ValueError: cannot convert float NaN to integer
